# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (177370, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    177006
# 1.0       363
# Name: count, dtype: int64

# %% [markdown]
# Highly Imbalanced data

# %%
#So we have to seperate the class data
legit=df[df.Class==0]
fraud=df[df.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (177006, 31)
# (363, 31)

# %%
legit.Amount.describe()
# Out:
# count    177006.000000
# mean         87.903224
# std         246.917598
# min           0.000000
# 25%           5.600000
# 50%          22.040000
# 75%          77.587500
# max       19656.530000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    63323.662915 -0.140233  0.020281  0.466717  0.095030 -0.153083
# 1.0    57192.110193 -5.992669  4.358197 -7.938391  4.859992 -4.342742
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.058747 -0.060296  0.026599  0.022408  ...  0.027272 -0.026450
# 1.0   -1.433287 -6.962503  0.738125 -2.840810  ...  0.413750  0.793917
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.074181 -0.020671  0.008056  0.084078  0.010817  0.001892  0.002362
# 1.0   -0.022636 -0.041697 -0.073078  0.078138  0.034990  0.181875  0.052434
#
#            Amount
# Class
# 0.0     87.903224
# 1.0    116.939697
#
# [2 rows x 30 columns]

# %% [markdown]
# UnderSampling

# %%
legit_sample=legit.sample(n=363)

# %% [markdown]
# Concatinating two Dataframe

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 80822    58666.0 -3.613572 -7.550789 -2.467398  3.402951 -2.542346  0.320732
# 89473    62590.0  0.602036 -2.348222 -0.398765 -0.888110 -1.482530 -0.378664
# 148200   89554.0  2.007350 -0.201276 -2.975007 -0.564539  2.592582  3.148763
# 176357  122730.0  1.806249 -0.545895  0.119610  1.090483 -0.525147  0.996295
# 159530  112608.0  2.321163 -1.448217 -1.310816 -1.824314 -0.850281 -0.025678
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 80822   3.568403 -0.791939 -0.340906  ...  1.521513 -1.029991 -2.267839
# 89473  -0.058660 -0.369984 -2.075771  ...  0.111469 -0.101176 -0.475870
# 148200 -0.394311  0.779978  0.357899  ... -0.342027 -1.005914  0.348492
# 176357 -1.110203  0.393245  1.066679  ...  0.312948  0.958284  0.120853
# 159530 -1.242175  0.038469 -1.280903  ... -0.181621 -0.111143  0.193278
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    363
# 1.0    363
# Name: count, dtype: int64

# %% [markdown]
# Data seperation

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']
print(x.shape)
print(y.shape)
# Out:
# (726, 30)
# (726,)

# %% [markdown]
# Train and test data Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,stratify=None,random_state=2)
print(x_train.shape)
print(x_test.shape)
# Out:
# (653, 30)
# (73, 30)

# %% [markdown]
# Model Training

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model_Evaluation

# %%
x_train_prediction=model.predict(x_train)
prediction=accuracy_score(y_train,x_train_prediction)
print(prediction)
# Out:
# 0.9525267993874426

# %% [markdown]
# Model testing

# %%
x_test_prediction=model.predict(x_test)
prediction=accuracy_score(y_test,x_test_prediction)
print(prediction)
# Out:
# 0.8767123287671232

# %% [markdown]
# Making Predictive System

# %%
input_data=(406,-2.312226542,1.951992011,-1.609850732,3.997905588,-0.522187865,-1.426545319,-2.537387306,1.391657248,-2.770089277,-2.772272145,3.202033207,-2.899907388,-0.595221881,-4.289253782,0.38972412,-1.14074718,-2.830055675,-0.016822468,0.416955705,0.126910559,0.517232371,-0.035049369,-0.465211076,0.320198199,0.044519167,0.177839798,0.261145003,-0.143275875,0)
numpy=np.asarray(input_data)
reshaped_numpy=numpy.reshape(1,-1)
prediction=model.predict(reshaped_numpy)
print(prediction)
# Out:
# [1.]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
